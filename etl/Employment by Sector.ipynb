# %%
import pandas as pd
import numpy as np
import os

from ddf_utils.str import to_concept_id
from ddf_utils.index import create_index_file

# %%
source = 'source/kilm04.xlsx'

# %%
data = pd.read_excel(source, skiprows=2)

# %%
data
# Out:
#      Country (code)         Country                   Region  \
# 0               ALB         Albania  Europe and Central Asia
# 1               ALB         Albania  Europe and Central Asia
# 2               ALB         Albania  Europe and Central Asia
# 3               ALB         Albania  Europe and Central Asia
# 4               ALB         Albania  Europe and Central Asia
# 5               ALB         Albania  Europe and Central Asia
# 6               ALB         Albania  Europe and Central Asia
# 7               ALB         Albania  Europe and Central Asia
# 8               ALB         Albania  Europe and Central Asia
# 9               ALB         Albania  Europe and Central Asia
# 10              ALB         Albania  Europe and Central Asia
# 11              DZA         Algeria                   Africa
# 12              DZA         Algeria                   Africa
# 13              DZA         Algeria                   Africa
# 14              DZA         Algeria                   Africa
# 15              DZA         Algeria                   Africa
# 16              DZA         Algeria                   Africa
# 17              DZA         Algeria                   Africa
# 18              DZA         Algeria                   Africa
# 19              DZA         Algeria                   Africa
# 20              DZA         Algeria                   Africa
# 21              DZA         Algeria                   Africa
# 22              DZA         Algeria                   Africa
# 23              ASM  American Samoa     Asia and the Pacific
# 24              ASM  American Samoa     Asia and the Pacific
# 25              ASM  American Samoa     Asia and the Pacific
# 26              ASM  American Samoa     Asia and the Pacific
# 27              ASM  American Samoa     Asia and the Pacific
# 28              AGO          Angola                   Africa
# 29              AIA        Anguilla                 Americas
# ...             ...             ...                      ...
# 8565            YEM           Yemen              Arab States
# 8566            YEM           Yemen              Arab States
# 8567            YEM           Yemen              Arab States
# 8568            YEM           Yemen              Arab States
# 8569            YEM           Yemen              Arab States
# 8570            ZMB          Zambia                   Africa
# 8571            ZMB          Zambia                   Africa
# 8572            ZMB          Zambia                   Africa
# 8573            ZMB          Zambia                   Africa
# 8574            ZMB          Zambia                   Africa
# 8575            ZMB          Zambia                   Africa
# 8576            ZMB          Zambia                   Africa
# 8577            ZMB          Zambia                   Africa
# 8578            ZMB          Zambia                   Africa
# 8579            ZMB          Zambia                   Africa
# 8580            ZMB          Zambia                   Africa
# 8581            ZMB          Zambia                   Africa
# 8582            ZMB          Zambia                   Africa
# 8583            ZMB          Zambia                   Africa
# 8584            ZMB          Zambia                   Africa
# 8585            ZMB          Zambia                   Africa
# 8586            ZWE        Zimbabwe                   Africa
# 8587            ZWE        Zimbabwe                   Africa
# 8588            ZWE        Zimbabwe                   Africa
# 8589            ZWE        Zimbabwe                   Africa
# 8590            ZWE        Zimbabwe                   Africa
# 8591            ZWE        Zimbabwe                   Africa
# 8592            ZWE        Zimbabwe                   Africa
# 8593            ZWE        Zimbabwe                   Africa
# 8594            ZWE        Zimbabwe                   Africa
#
#                          Sub-region (broad) Sub-region (detailed)  \
# 0     Northern, Southern and Western Europe       Southern Europe
# 1     Northern, Southern and Western Europe       Southern Europe
# 2     Northern, Southern and Western Europe       Southern Europe
# 3     Northern, Southern and Western Europe       Southern Europe
# 4     Northern, Southern and Western Europe       Southern Europe
# 5     Northern, Southern and Western Europe       Southern Europe
# 6     Northern, Southern and Western Europe       Southern Europe
# 7     Northern, Southern and Western Europe       Southern Europe
# 8     Northern, Southern and Western Europe       Southern Europe
# 9     Northern, Southern and Western Europe       Southern Europe
# 10    Northern, Southern and Western Europe       Southern Europe
# 11                          Northern Africa                   NaN
# 12                          Northern Africa                   NaN
# 13                          Northern Africa                   NaN
# 14                          Northern Africa                   NaN
# 15                          Northern Africa                   NaN
# 16                          Northern Africa                   NaN
# 17                          Northern Africa                   NaN
# 18                          Northern Africa                   NaN
# 19                          Northern Africa                   NaN
# 20                          Northern Africa                   NaN
# 21                          Northern Africa                   NaN
# 22                          Northern Africa                   NaN
# 23       South-Eastern Asia and the Pacific       Pacific Islands
# 24       South-Eastern Asia and the Pacific       Pacific Islands
# 25       South-Eastern Asia and the Pacific       Pacific Islands
# 26       South-Eastern Asia and the Pacific       Pacific Islands
# 27       South-Eastern Asia and the Pacific       Pacific Islands
# 28                       Sub-Saharan Africa        Central Africa
# 29          Latin America and the Caribbean             Caribbean
# ...                                     ...                   ...
# 8565                                    NaN                   NaN
# 8566                                    NaN                   NaN
# 8567                                    NaN                   NaN
# 8568                                    NaN                   NaN
# 8569                                    NaN                   NaN
# 8570                     Sub-Saharan Africa        Eastern Africa
# 8571                     Sub-Saharan Africa        Eastern Africa
# 8572                     Sub-Saharan Africa        Eastern Africa
# 8573                     Sub-Saharan Africa        Eastern Africa
# 8574                     Sub-Saharan Africa        Eastern Africa
# 8575                     Sub-Saharan Africa        Eastern Africa
# 8576                     Sub-Saharan Africa        Eastern Africa
# 8577                     Sub-Saharan Africa        Eastern Africa
# 8578                     Sub-Saharan Africa        Eastern Africa
# 8579                     Sub-Saharan Africa        Eastern Africa
# 8580                     Sub-Saharan Africa        Eastern Africa
# 8581                     Sub-Saharan Africa        Eastern Africa
# 8582                     Sub-Saharan Africa        Eastern Africa
# 8583                     Sub-Saharan Africa        Eastern Africa
# 8584                     Sub-Saharan Africa        Eastern Africa
# 8585                     Sub-Saharan Africa        Eastern Africa
# 8586                     Sub-Saharan Africa        Eastern Africa
# 8587                     Sub-Saharan Africa        Eastern Africa
# 8588                     Sub-Saharan Africa        Eastern Africa
# 8589                     Sub-Saharan Africa        Eastern Africa
# 8590                     Sub-Saharan Africa        Eastern Africa
# 8591                     Sub-Saharan Africa        Eastern Africa
# 8592                     Sub-Saharan Africa        Eastern Africa
# 8593                     Sub-Saharan Africa        Eastern Africa
# 8594                     Sub-Saharan Africa        Eastern Africa
#
#      Income group (code)         Income group    B  Year Sex (code)  ...    \
# 0                    III  Upper-middle income  NaN  2000         MF  ...
# 1                    III  Upper-middle income  NaN  2001         MF  ...
# 2                    III  Upper-middle income  NaN  2002         MF  ...
# 3                    III  Upper-middle income  NaN  2003         MF  ...
# 4                    III  Upper-middle income  NaN  2004         MF  ...
# 5                    III  Upper-middle income  NaN  2005         MF  ...
# 6                    III  Upper-middle income  NaN  2006         MF  ...
# 7                    III  Upper-middle income    b  2007         MF  ...
# 8                    III  Upper-middle income    b  2009         MF  ...
# 9                    III  Upper-middle income    b  2009          M  ...
# 10                   III  Upper-middle income    b  2009          F  ...
# 11                   III  Upper-middle income  NaN  2001         MF  ...
# 12                   III  Upper-middle income  NaN  2001          M  ...
# 13                   III  Upper-middle income  NaN  2001          F  ...
# 14                   III  Upper-middle income  NaN  2003         MF  ...
# 15                   III  Upper-middle income  NaN  2003          M  ...
# 16                   III  Upper-middle income  NaN  2003          F  ...
# 17                   III  Upper-middle income  NaN  2004         MF  ...
# 18                   III  Upper-middle income  NaN  2004          M  ...
# 19                   III  Upper-middle income  NaN  2004          F  ...
# 20                   III  Upper-middle income  NaN  2011         MF  ...
# 21                   III  Upper-middle income  NaN  2011          M  ...
# 22                   III  Upper-middle income  NaN  2011          F  ...
# 23                   III  Upper-middle income  NaN  1990         MF  ...
# 24                   III  Upper-middle income  NaN  1990          M  ...
# 25                   III  Upper-middle income  NaN  1990          F  ...
# 26                   III  Upper-middle income  NaN  2000         MF  ...
# 27                   III  Upper-middle income    b  2010         MF  ...
# 28                   III  Upper-middle income  NaN  1992         MF  ...
# 29                   III  Upper-middle income  NaN  1999         MF  ...
# ...                  ...                  ...  ...   ...        ...  ...
# 8565                  II  Lower-middle income    b  2004          M  ...
# 8566                  II  Lower-middle income    b  2004          F  ...
# 8567                  II  Lower-middle income  NaN  2010         MF  ...
# 8568                  II  Lower-middle income  NaN  2010          M  ...
# 8569                  II  Lower-middle income  NaN  2010          F  ...
# 8570                  II  Lower-middle income  NaN  1990         MF  ...
# 8571                  II  Lower-middle income  NaN  1990          M  ...
# 8572                  II  Lower-middle income  NaN  1990          F  ...
# 8573                  II  Lower-middle income    b  1998         MF  ...
# 8574                  II  Lower-middle income    b  1998          M  ...
# 8575                  II  Lower-middle income    b  1998          F  ...
# 8576                  II  Lower-middle income    b  2000         MF  ...
# 8577                  II  Lower-middle income    b  2000          M  ...
# 8578                  II  Lower-middle income    b  2000          F  ...
# 8579                  II  Lower-middle income    b  2005         MF  ...
# 8580                  II  Lower-middle income    b  2005          M  ...
# 8581                  II  Lower-middle income    b  2005          F  ...
# 8582                  II  Lower-middle income  NaN  2008         MF  ...
# 8583                  II  Lower-middle income    b  2012         MF  ...
# 8584                  II  Lower-middle income    b  2012          M  ...
# 8585                  II  Lower-middle income    b  2012          F  ...
# 8586                   I           Low income  NaN  1999         MF  ...
# 8587                   I           Low income  NaN  1999          M  ...
# 8588                   I           Low income  NaN  1999          F  ...
# 8589                   I           Low income    b  2004         MF  ...
# 8590                   I           Low income    b  2004          M  ...
# 8591                   I           Low income    b  2004          F  ...
# 8592                   I           Low income  NaN  2011         MF  ...
# 8593                   I           Low income  NaN  2011          M  ...
# 8594                   I           Low income  NaN  2011          F  ...
#
#                                                    ISIC  Coverage (code)  \
# 0     International Standard Industrial Classificati...                T
# 1     International Standard Industrial Classificati...                T
# 2     International Standard Industrial Classificati...                T
# 3     International Standard Industrial Classificati...                T
# 4     International Standard Industrial Classificati...                T
# 5     International Standard Industrial Classificati...                T
# 6     International Standard Industrial Classificati...                T
# 7     International Standard Industrial Classificati...                T
# 8     International Standard Industrial Classificati...                C
# 9     International Standard Industrial Classificati...                C
# 10    International Standard Industrial Classificati...                C
# 11    International Standard Industrial Classificati...                T
# 12    International Standard Industrial Classificati...                T
# 13    International Standard Industrial Classificati...                T
# 14    International Standard Industrial Classificati...                T
# 15    International Standard Industrial Classificati...                T
# 16    International Standard Industrial Classificati...                T
# 17    International Standard Industrial Classificati...                T
# 18    International Standard Industrial Classificati...                T
# 19    International Standard Industrial Classificati...                T
# 20    International Standard Industrial Classificati...                T
# 21    International Standard Industrial Classificati...                T
# 22    International Standard Industrial Classificati...                T
# 23    International Standard Industrial Classificati...                T
# 24    International Standard Industrial Classificati...                T
# 25    International Standard Industrial Classificati...                T
# 26    International Standard Industrial Classificati...                T
# 27    International Standard Industrial Classificati...                T
# 28    International Standard Industrial Classificati...                T
# 29    International Standard Industrial Classificati...                C
# ...                                                 ...              ...
# 8565  International Standard Industrial Classificati...                T
# 8566  International Standard Industrial Classificati...                T
# 8567  International Standard Industrial Classificati...                T
# 8568  International Standard Industrial Classificati...                T
# 8569  International Standard Industrial Classificati...                T
# 8570  International Standard Industrial Classificati...              ...
# 8571  International Standard Industrial Classificati...              ...
# 8572  International Standard Industrial Classificati...              ...
# 8573  International Standard Industrial Classificati...                T
# 8574  International Standard Industrial Classificati...                T
# 8575  International Standard Industrial Classificati...                T
# 8576  International Standard Industrial Classificati...                T
# 8577  International Standard Industrial Classificati...                T
# 8578  International Standard Industrial Classificati...                T
# 8579  International Standard Industrial Classificati...                T
# 8580  International Standard Industrial Classificati...                T
# 8581  International Standard Industrial Classificati...                T
# 8582  International Standard Industrial Classificati...                T
# 8583  International Standard Industrial Classificati...                T
# 8584  International Standard Industrial Classificati...                T
# 8585  International Standard Industrial Classificati...                T
# 8586  International Standard Industrial Classificati...                C
# 8587  International Standard Industrial Classificati...                C
# 8588  International Standard Industrial Classificati...                C
# 8589  International Standard Industrial Classificati...                C
# 8590  International Standard Industrial Classificati...                C
# 8591  International Standard Industrial Classificati...                C
# 8592  International Standard Industrial Classificati...                T
# 8593  International Standard Industrial Classificati...                T
# 8594  International Standard Industrial Classificati...                T
#
#            Coverage    Age      Reference period  Geographic limitation  \
# 0             Total    15+                   NaN                    NaN
# 1             Total    15+                   NaN                    NaN
# 2             Total    15+                   NaN                    NaN
# 3             Total    15+                   NaN                    NaN
# 4             Total    15+                   NaN                    NaN
# 5             Total    15+                   NaN                    NaN
# 6             Total    15+                   NaN                    NaN
# 7             Total  15-64                   NaN                    NaN
# 8          Civilian    15+      Noncalendar year                    NaN
# 9          Civilian    15+      Noncalendar year                    NaN
# 10         Civilian    15+      Noncalendar year                    NaN
# 11            Total    15+             September                    NaN
# 12            Total    15+             September                    NaN
# 13            Total    15+             September                    NaN
# 14            Total    15+             September                    NaN
# 15            Total    15+             September                    NaN
# 16            Total    15+             September                    NaN
# 17            Total    15+             September                    NaN
# 18            Total    15+             September                    NaN
# 19            Total    15+             September                    NaN
# 20            Total    15+        Fourth quarter                    NaN
# 21            Total    15+        Fourth quarter                    NaN
# 22            Total    15+        Fourth quarter                    NaN
# 23            Total    16+                   NaN                    NaN
# 24            Total    16+                   NaN                    NaN
# 25            Total    16+                   NaN                    NaN
# 26            Total    16+                   NaN                    NaN
# 27            Total    16+                   NaN                    NaN
# 28            Total    ...                   NaN                 Luanda
# 29         Civilian    15+             September                    NaN
# ...             ...    ...                   ...                    ...
# 8565          Total    15+                   NaN                    NaN
# 8566          Total    15+                   NaN                    NaN
# 8567          Total  15-65                   NaN                    NaN
# 8568          Total  15-65                   NaN                    NaN
# 8569          Total  15-65                   NaN                    NaN
# 8570  Not available    12+                August                    NaN
# 8571  Not available    12+                August                    NaN
# 8572  Not available    12+                August                    NaN
# 8573          Total    12+  November to December                    NaN
# 8574          Total    12+  November to December                    NaN
# 8575          Total    12+  November to December                    NaN
# 8576          Total    12+               October                    NaN
# 8577          Total    12+               October                    NaN
# 8578          Total    12+               October                    NaN
# 8579          Total    15+  November to December                    NaN
# 8580          Total    15+  November to December                    NaN
# 8581          Total    15+  November to December                    NaN
# 8582          Total    ...                   NaN                    NaN
# 8583          Total    15+                   NaN                    NaN
# 8584          Total    15+                   NaN                    NaN
# 8585          Total    15+                   NaN                    NaN
# 8586       Civilian    15+                  June                    NaN
# 8587       Civilian    15+                  June                    NaN
# 8588       Civilian    15+                  June                    NaN
# 8589       Civilian    15+                  June                    NaN
# 8590       Civilian    15+                  June                    NaN
# 8591       Civilian    15+                  June                    NaN
# 8592          Total    15+                  June                    NaN
# 8593          Total    15+                  June                    NaN
# 8594          Total    15+                  June                    NaN
#
#                      Coverage limitation  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# 5                                    NaN
# 6                                    NaN
# 7                                    NaN
# 8     Excluding institutional population
# 9     Excluding institutional population
# 10    Excluding institutional population
# 11                                   NaN
# 12                                   NaN
# 13                                   NaN
# 14                                   NaN
# 15                                   NaN
# 16                                   NaN
# 17                                   NaN
# 18                                   NaN
# 19                                   NaN
# 20                                   NaN
# 21                                   NaN
# 22                                   NaN
# 23                                   NaN
# 24                                   NaN
# 25                                   NaN
# 26                                   NaN
# 27                                   NaN
# 28                                   NaN
# 29                                   NaN
# ...                                  ...
# 8565                                 NaN
# 8566                                 NaN
# 8567                                 NaN
# 8568                                 NaN
# 8569                                 NaN
# 8570                                 NaN
# 8571                                 NaN
# 8572                                 NaN
# 8573                                 NaN
# 8574                                 NaN
# 8575                                 NaN
# 8576                                 NaN
# 8577                                 NaN
# 8578                                 NaN
# 8579                                 NaN
# 8580                                 NaN
# 8581                                 NaN
# 8582                                 NaN
# 8583                                 NaN
# 8584                                 NaN
# 8585                                 NaN
# 8586                                 NaN
# 8587                                 NaN
# 8588                                 NaN
# 8589                                 NaN
# 8590                                 NaN
# 8591                                 NaN
# 8592                                 NaN
# 8593                                 NaN
# 8594                                 NaN
#
#                                   Classification remark  Survey limitation  \
# 0                                                   NaN                NaN
# 1                                                   NaN                NaN
# 2                                                   NaN                NaN
# 3                                                   NaN                NaN
# 4                                                   NaN                NaN
# 5                                                   NaN                NaN
# 6                                                   NaN                NaN
# 7                                                   NaN                NaN
# 8                                                   NaN                NaN
# 9                                                   NaN                NaN
# 10                                                  NaN                NaN
# 11                                                  NaN                NaN
# 12                                                  NaN                NaN
# 13                                                  NaN                NaN
# 14                                                  NaN                NaN
# 15                                                  NaN                NaN
# 16                                                  NaN                NaN
# 17                                                  NaN                NaN
# 18                                                  NaN                NaN
# 19                                                  NaN                NaN
# 20                                                  NaN                NaN
# 21                                                  NaN                NaN
# 22                                                  NaN                NaN
# 23                                                  NaN                NaN
# 24                                                  NaN                NaN
# 25                                                  NaN                NaN
# 26                                                  NaN                NaN
# 27                                                  NaN                NaN
# 28                                                  NaN                NaN
# 29           Agriculture includes mining and quarrying.                NaN
# ...                                                 ...                ...
# 8565                                                NaN                NaN
# 8566                                                NaN                NaN
# 8567                                                NaN                NaN
# 8568                                                NaN                NaN
# 8569                                                NaN                NaN
# 8570                                                NaN                NaN
# 8571                                                NaN                NaN
# 8572                                                NaN                NaN
# 8573                                                NaN                NaN
# 8574                                                NaN                NaN
# 8575                                                NaN                NaN
# 8576                                                NaN                NaN
# 8577                                                NaN                NaN
# 8578                                                NaN                NaN
# 8579                                                NaN                NaN
# 8580                                                NaN                NaN
# 8581                                                NaN                NaN
# 8582                                                NaN                NaN
# 8583                                                NaN                NaN
# 8584                                                NaN                NaN
# 8585                                                NaN                NaN
# 8586  Services includes Activities not adequately de...                NaN
# 8587  Services includes Activities not adequately de...                NaN
# 8588  Services includes Activities not adequately de...                NaN
# 8589                                                NaN                NaN
# 8590                                                NaN                NaN
# 8591                                                NaN                NaN
# 8592                                                NaN                NaN
# 8593                                                NaN                NaN
# 8594                                                NaN                NaN
#
#       Notes
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
# 6       NaN
# 7       NaN
# 8       NaN
# 9       NaN
# 10      NaN
# 11      NaN
# 12      NaN
# 13      NaN
# 14      NaN
# 15      NaN
# 16      NaN
# 17      NaN
# 18      NaN
# 19      NaN
# 20      NaN
# 21      NaN
# 22      NaN
# 23      NaN
# 24      NaN
# 25      NaN
# 26      NaN
# 27      NaN
# 28      NaN
# 29      NaN
# ...     ...
# 8565    NaN
# 8566    NaN
# 8567    NaN
# 8568    NaN
# 8569    NaN
# 8570    NaN
# 8571    NaN
# 8572    NaN
# 8573    NaN
# 8574    NaN
# 8575    NaN
# 8576    NaN
# 8577    NaN
# 8578    NaN
# 8579    NaN
# 8580    NaN
# 8581    NaN
# 8582    NaN
# 8583    NaN
# 8584    NaN
# 8585    NaN
# 8586    NaN
# 8587    NaN
# 8588    NaN
# 8589    NaN
# 8590    NaN
# 8591    NaN
# 8592    NaN
# 8593    NaN
# 8594    NaN
#
# [8595 rows x 35 columns]

# %%
data.columns
# Out:
# Index(['Country (code)', 'Country', 'Region', 'Sub-region (broad)',
#        'Sub-region (detailed)', 'Income group (code)', 'Income group', 'B',
#        'Year', 'Sex (code)', 'Sex', 'Total employment ('000)',
#        'Agriculture ('000)', 'Agriculture (%)', 'Industry ('000)',
#        'Industry (%)', 'Services ('000)', 'Services (%)',
#        'Not adequately defined ('000)', 'Not adequately defined (%)',
#        'Repository (code)', 'Repository', 'Type of source (code)',
#        'Type of source', 'ISIC (code)', 'ISIC', 'Coverage (code)', 'Coverage',
#        'Age', 'Reference period', 'Geographic limitation',
#        'Coverage limitation', 'Classification remark', 'Survey limitation',
#        'Notes'],
#       dtype='object')

# %%
# country

# %%
country = data[['Country (code)', 'Country']].drop_duplicates().copy()

# %%
country.columns = ['country', 'name']

# %%
country['country'] = country['country'].map(to_concept_id)

# %%
country.to_csv('../ddf--entities--country.csv', index=False)

# %%
# sex

# %%
sex = data[['Sex (code)', 'Sex']].drop_duplicates().copy()
sex.columns = ['sex', 'name']

sex['sex'] = sex['sex'].map(to_concept_id)

sex.to_csv('../ddf--entities--sex.csv', index=False)

# %%
# concepts

# %%
discs = ['Name', 'Year', 'Country', 'Sex']

conc = data.columns[11:20]

# %%
conc
# Out:
# Index(['Total employment ('000)', 'Agriculture ('000)', 'Agriculture (%)',
#        'Industry ('000)', 'Industry (%)', 'Services ('000)', 'Services (%)',
#        'Not adequately defined ('000)', 'Not adequately defined (%)'],
#       dtype='object')

# %%
cdf = pd.DataFrame([], columns=['concept', 'name', 'concept_type'])

cdf['name'] = [*discs, *conc]

cdf['concept'] = cdf['name'].map(to_concept_id)

# %%
cdf.loc[4:, 'concept_type'] = 'measure'
cdf.loc[0, 'concept_type'] = 'string'
cdf.loc[1, 'concept_type'] = 'time'
cdf.loc[2:3, 'concept_type'] = 'entity_domain'

# %%
cdf
# Out:
#                        concept                           name   concept_type
# 0                         name                           Name         string
# 1                         year                           Year           time
# 2                      country                        Country  entity_domain
# 3                          sex                            Sex  entity_domain
# 4         total_employment_000        Total employment ('000)        measure
# 5              agriculture_000             Agriculture ('000)        measure
# 6                  agriculture                Agriculture (%)        measure
# 7                 industry_000                Industry ('000)        measure
# 8                     industry                   Industry (%)        measure
# 9                 services_000                Services ('000)        measure
# 10                    services                   Services (%)        measure
# 11  not_adequately_defined_000  Not adequately defined ('000)        measure
# 12      not_adequately_defined     Not adequately defined (%)        measure

# %%
cdf.to_csv('../ddf--concepts.csv', index=False)

# %%
# datapoints

# %%
dps = data[['Country (code)', 'Sex (code)', 'Year', *conc]].copy()

# %%
dps.columns = ['country', 'sex', 'year', *[to_concept_id(x) for x in conc]]

# %%
dps['country'] = dps['country'].map(to_concept_id)
dps['sex'] = dps['sex'].map(to_concept_id)

# %%
dps = dps.set_index(['country', 'sex', 'year'])

# %%
for k, df in dps.items():
    df_ = df.reset_index()
    path = '../ddf--datapoints--{}--by--country--sex--year.csv'.format(k)
    df_.to_csv(path, index=False)

# %%
create_index_file('../')
# Out:
#                 key                       value  \
# 0           concept                        name
# 1           concept                concept_type
# 0  country,sex,year                 agriculture
# 0  country,sex,year             agriculture_000
# 0  country,sex,year                    industry
# 0  country,sex,year                industry_000
# 0  country,sex,year      not_adequately_defined
# 0  country,sex,year  not_adequately_defined_000
# 0  country,sex,year                    services
# 0  country,sex,year                services_000
# 0  country,sex,year        total_employment_000
# 0           country                        name
# 0               sex                        name
#
#                                                 file
# 0                                  ddf--concepts.csv
# 1                                  ddf--concepts.csv
# 0  ddf--datapoints--agriculture--by--country--sex...
# 0  ddf--datapoints--agriculture_000--by--country-...
# 0  ddf--datapoints--industry--by--country--sex--y...
# 0  ddf--datapoints--industry_000--by--country--se...
# 0  ddf--datapoints--not_adequately_defined--by--c...
# 0  ddf--datapoints--not_adequately_defined_000--b...
# 0  ddf--datapoints--services--by--country--sex--y...
# 0  ddf--datapoints--services_000--by--country--se...
# 0  ddf--datapoints--total_employment_000--by--cou...
# 0                         ddf--entities--country.csv
# 0                             ddf--entities--sex.csv
